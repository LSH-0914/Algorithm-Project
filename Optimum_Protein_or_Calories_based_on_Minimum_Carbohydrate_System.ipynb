# %%
import pandas as pd
import math
from collections import OrderedDict
df = pd.read_csv("//content//nutrients_csvfile.csv",encoding='latin1')
df
# Out:
#                            Food    Measure  Grams  Calories  Protein  Fat  \
# 0                    Cows' milk      1 qt.    100       660       32   40
# 1                     Milk skim      1 qt.    100       360       36    0
# 2                    Buttermilk      1 cup    100       127        9    5
# 3       Eggs Scrambled or fried          2    100       220       13   16
# 4                         Bacon   2 slices    100        95        4    8
# 5       Corned beef hash canned      3 oz.    100       120       12    8
# 6                       Pot-pie      1 pie    100       480       18   28
# 7         Corned beef hash Stew      1 cup    100       185       15   10
# 8                         Clams      3 oz.    100        87       12    1
# 9                      Scallops  3 1/2 oz.    100       104       18    8
# 10                    Asparagus   6 spears    100        18        1    0
# 11                        Beans      1 cup    100        25        1    0
# 12                         Lima      1 cup    100       140        8    0
# 13            Lima, dry, cooked      1 cup    100       260       16    0
# 14        Navy, baked with pork    3/4 cup    100       250       11    6
# 15                   Red kidney      1 cup    100       230       15    1
# 16                 Bean sprouts      1 cup    100        17        1    0
# 17                  Beet greens      1 cup    100        27        2    0
# 18                    Beetroots      1 cup    100         1       12    0
# 19                     Broccoli      1 cup    100        45        5    0
# 20             Brussels sprouts      1 cup    100        60        6    0
# 21                   Sauerkraut      1 cup    100        32        1    0
# 22              Steamed cabbage      1 cup    100        40        2    0
# 23                      Carrots      1 cup    100        45        1    0
# 24        Watercress stems, raw      1 cup    100         9        1    0
# 25                       Banana     1 med.    100        85        1    0
# 26                 Blackberries      1 cup    100        85        2    1
# 27                  Blueberries      1 cup    100       245        1    0
# 28                   Cantaloupe   1/2 med.    100        40        1    0
# 29                     Cherries      1 cup    100       100        2    1
# 30                   Fresh, raw      1 cup    100        65        1    0
# 31                        Dates      1 cup    100       505        4    0
# 32                     Biscuits          1    100       130        3    4
# 33                  Bran flakes      1 cup    100       117        3    0
# 34         Bread, cracked wheat    1 slice    100        60        2    1
# 35                      Waffles          1    100       240        8    9
# 36                   Wheat germ      1 cup    100       245       17    7
# 37    Wheat-germ cereal toasted      1 cup    100       260       20    7
# 38  Wheat meal cereal unrefined    3/4 cup    100       103        4    1
# 39                Wheat, cooked    3/4 cup    100       275       12    1
# 40                   Bean soups      1 cup    100       190        8    5
# 41                      Almonds    1/2 cup    100       425       13   38
# 42           roasted and salted    1/2 cup    100       439       13   40
# 43                  Brazil nuts    1/2 cup    100       457       10   47
# 44                      Cashews    1/2 cup    100       392       12   32
#
#     Sat.Fat  Fiber  Carbs                          Category  Protein/100g  \
# 0      36.0    0.0   48.0                    Dairy products          3.28
# 1       0.0    0.0   52.0                    Dairy products          3.66
# 2       4.0    0.0   13.0                    Dairy products          3.66
# 3      14.0    0.0    1.0                    Dairy products         10.16
# 4       7.0    0.0    1.0                     Meat, Poultry         25.00
# 5       7.0    0.0    6.0                     Meat, Poultry         14.12
# 6      25.0    0.0   32.0                     Meat, Poultry          7.93
# 7       9.0    0.0   15.0                     Meat, Poultry          6.38
# 8       0.0    0.0    2.0                     Fish, Seafood         14.12
# 9       0.0    0.0   10.0                     Fish, Seafood         18.00
# 10      0.0    0.5    3.0                    Vegetables A-E          1.04
# 11      0.0    0.8    6.0                    Vegetables A-E          0.80
# 12      0.0    3.0   24.0                    Vegetables A-E          5.00
# 13      0.0    2.0   48.0                    Vegetables A-E          8.33
# 14      6.0    2.0   37.0                    Vegetables A-E          5.50
# 15      0.0    2.5   42.0                    Vegetables A-E          5.77
# 16      0.0    0.3    3.0                    Vegetables A-E          2.00
# 17      0.0    1.4    6.0                    Vegetables A-E          2.00
# 18      NaN    0.0    0.8                    Vegetables A-E          7.27
# 19      0.0    1.9    8.0                    Vegetables A-E          3.33
# 20      0.0    1.7   12.0                    Vegetables A-E          4.62
# 21      0.0    1.2    7.0                    Vegetables A-E          0.67
# 22      0.0    1.3    9.0                    Vegetables A-E          1.18
# 23      0.0    0.9   10.0                    Vegetables A-E          0.67
# 24      0.0    0.3    1.0                        Fruits A-F          2.00
# 25      0.0    0.9   23.0                        Fruits A-F          0.67
# 26      0.0    6.6   19.0                        Fruits A-F          1.39
# 27      0.0    2.0   65.0                        Fruits A-F          0.40
# 28      0.0    2.2    9.0                        Fruits A-F          0.26
# 29      0.0    2.0   26.0                        Fruits A-F          0.78
# 30      0.0    0.8   15.0                        Fruits A-F          0.88
# 31      0.0    3.6  134.0                        Fruits A-F          2.25
# 32      3.0    0.0   18.0  Breads, cereals, fastfood,grains          7.89
# 33      0.0    0.1   32.0  Breads, cereals, fastfood,grains         12.00
# 34      1.0    0.1   12.0  Breads, cereals, fastfood,grains          8.70
# 35      1.0    0.1   30.0  Breads, cereals, fastfood,grains         10.67
# 36      3.0    2.5   34.0  Breads, cereals, fastfood,grains         25.00
# 37      3.0    2.5   36.0  Breads, cereals, fastfood,grains         30.77
# 38      0.0    0.7   25.0  Breads, cereals, fastfood,grains         13.33
# 39      0.0    4.4   35.0  Breads, cereals, fastfood,grains          6.00
# 40      4.0    0.6   30.0                             Soups          3.20
# 41     28.0    1.8   13.0                    Seeds and Nuts         18.57
# 42     31.0    1.8   13.0                    Seeds and Nuts         18.57
# 43     31.0    2.0    7.0                    Seeds and Nuts         14.29
# 44     28.0    0.9   20.0                    Seeds and Nuts         17.14
#
#     Carbs/100g  Calories/100g
# 0         4.92           6.60
# 1         5.28           3.60
# 2         5.28           1.27
# 3         0.78           2.20
# 4         6.25           0.95
# 5         7.06           1.20
# 6        14.10           4.80
# 7         6.38           1.85
# 8         2.35           0.87
# 9        10.00           1.04
# 10        3.13           0.18
# 11        4.80           0.25
# 12       15.00           1.40
# 13       25.00           2.60
# 14       18.50           2.50
# 15       16.15           2.30
# 16        6.00           0.17
# 17        6.00           0.27
# 18        0.48           0.01
# 19        5.33           0.45
# 20        9.23           0.60
# 21        4.67           0.32
# 22        5.29           0.40
# 23        6.67           0.45
# 24        2.00           0.09
# 25       15.33           0.85
# 26       13.19           0.85
# 27       26.00           2.45
# 28        2.37           0.40
# 29       10.12           1.00
# 30       13.16           0.65
# 31       75.28           5.05
# 32       47.37           1.30
# 33      128.00           1.17
# 34       52.17           0.60
# 35       40.00           2.40
# 36       50.00           2.45
# 37       55.38           2.60
# 38       83.33           1.03
# 39       17.50           2.75
# 40       12.00           1.90
# 41       18.57           4.25
# 42       18.57           4.39
# 43       10.00           4.57
# 44       28.57           3.92

# %%
category = []
for i in range(0,len(df)):
  category.append(df["Category"][i])

test_list = list(OrderedDict.fromkeys(category))

# %%
print(len(test_list))
# Out:
# 8

# %%
print("Category: ")

for i in test_list:
  print(i)
a = input("\nEnter your allergies: ")
# Out:
# Category:
# Dairy products
# Meat, Poultry
# Fish, Seafood
# Vegetables A-E
# Fruits A-F
# Breads, cereals, fastfood,grains
# Soups
# Seeds and Nuts
#
# Enter your allergies: Meat, Poultry

# %%
food = []
carbs = []
protein = []
b = input("Do you want to choose Protein or Calories to be maximized? Please enter P for Protein or C for Calories:  ")
if(b == "P"):
  target = "Protein"
  for i in range(0,len(df)):
    if(df["Category"][i] != a):
      food.append(df["Food"][i])
      protein.append(math.ceil(df["Protein/100g"][i]))
      carbs.append(math.ceil(df["Carbs/100g"][i]))
else:
  target = "Calories"
  for i in range(0,len(df)):
    if(df["Category"][i] != a):
      food.append(df["Food"][i])
      protein.append(math.ceil(df["Calories/100g"][i]))
      carbs.append(math.ceil(df["Carbs/100g"][i]))
# Out:
# Do you want to choose Protein or Calories to be maximized? Please enter P for Protein or C for Calories:  P

# %%
prioritize = []
prioritize1 = []
prioritize2 = []

for i in food:

  print(i)

a = "Y"
while(a == "Y"):
  c = input("What food items would you like to prioritize?\n")
  quantity = int(input("Quantity of this type of food item would you like to consume(*100g)?\n"))
  for i in range(0,len(food)):
    if food[i] == c:
      for j in range(0,quantity):
        prioritize.append(food[i])
        prioritize1.append(protein[i])
        prioritize2.append(carbs[i])
      
  a = input("Press Y to enter more food prioritization or N to finish: ")

for i in range(0,len(prioritize)):
  print(prioritize[i])
  print(prioritize1[i])
  print(prioritize2[i])
# Out:
# Cows' milk
# Milk skim
# Buttermilk
# Eggs Scrambled or fried
# Clams
# Scallops
# Asparagus
# Beans
# Lima
# Lima, dry, cooked
# Navy, baked with pork
# Red kidney
# Bean sprouts
# Beet greens
# Beetroots
# Broccoli
# Brussels sprouts
# Sauerkraut
# Steamed cabbage
# Carrots
# Watercress stems, raw
# Banana
# Blackberries
# Blueberries
# Cantaloupe
# Cherries
# Fresh, raw
# Dates
# Biscuits
# Bran flakes
# Bread, cracked wheat
# Waffles
# Wheat germ
# Wheat-germ cereal toasted
# Wheat meal cereal unrefined
# Wheat, cooked
# Bean soups
# Almonds
# roasted and salted
# Brazil nuts
# Cashews
# What food items would you like to prioritize?
# Banana
# Quantity of this type of food item would you like to consume(*100g)?
# 2
# Press Y to enter more food prioritization or N to finish: Y
# What food items would you like to prioritize?
# Almonds
# Quantity of this type of food item would you like to consume(*100g)?
# 3
# Press Y to enter more food prioritization or N to finish: N
# Banana
# 1
# 16
# Banana
# 1
# 16
# Almonds
# 19
# 19
# Almonds
# 19
# 19
# Almonds
# 19
# 19

# %%
new_prioritize = list(set(prioritize))
print(new_prioritize)
for j in range(0, len(new_prioritize)):
  a =food.index(new_prioritize[j])
  food.remove(new_prioritize[j])
  protein.pop(a)
  carbs.pop(a)
# Out:
# ['Banana', 'Almonds']

# %%
print(new_prioritize)
# Out:
# ['Banana', 'Almonds']

# %%
print(prioritize)
# Out:
# ['Banana', 'Banana', 'Almonds', 'Almonds', 'Almonds']

# %%
print(prioritize2)
# Out:
# [16, 16, 19, 19, 19]

# %%
# carbs = prioritize2 + carbs
# protein = prioritize1 + protein
# food = prioritize + food

# A naive recursive implementation
# of 0-1 Knapsack Problem
 
# Returns the maximum value that
# can be put in a knapsack of
# capacity W
 

# Python3 code for Dynamic Programming
# based solution for 0-1 Knapsack problem
 
# Prints the items which are put in a
# knapsack of capacity W
def printknapSack(W, name, wt, val, n,prioritize,prioritize1,prioritize2,sum,target):
    K = [[0 for w in range(W + 1)]
            for i in range(n + 1)]
             
    # Build table K[][] in bottom
    # up manner
    for i in range(n + 1):
        for w in range(W + 1):
            if i == 0 or w == 0:
                K[i][w] = 0
            elif wt[i - 1] <= w:
                K[i][w] = max(val[i - 1]
                  + K[i - 1][w - wt[i - 1]],
                               K[i - 1][w])
            else:
                K[i][w] = K[i - 1][w]
 
    # stores the result of Knapsack
    res = K[n][W]
    print("Optimum "+ target+"(g) obtained by Knapsack 0-1 algorithm: "+str(res + total1)+ "\n")
    print("The distribution of Carbohydrate and", target ,"as well as suggested food are displayed as below: \n")
    print("Carbohydrate(g)\t"+ target +"\tQuantity"+"\tFood")
    count = 0
    prioritize_item = prioritize[0]
    for i in range(0,len(prioritize)):
      if (prioritize_item == prioritize[i]):
        count+=1
        if(count == prioritize.count(prioritize[i])):
          print(str(prioritize2[i] * count)+"\t\t"+str(prioritize1[i] * count)+ "\t"+str(count)+"\t\t"+str(prioritize[i]))
          count = 0
      else:
        count+=1
        if(count == prioritize.count(prioritize[i])):
          print(str(prioritize2[i] * count)+"\t\t"+str(prioritize1[i] * count)+ "\t"+str(count)+"\t\t"+str(prioritize[i]))
          count = 0
     
    w = W
    for i in range(n, 0, -1):
        if res <= 0:
            break
        # either the result comes from the
        # top (K[i-1][w]) or from (val[i-1]
        # + K[i-1] [w-wt[i-1]]) as in Knapsack
        # table. If it comes from the latter
        # one/ it means the item is included.
        if res == K[i - 1][w]:
            continue
        else:
 
            # This item is included.
            print(str(wt[i - 1])+"\t\t"+str(val[i-1])+"\t"+str(1)+"\t\t"+name[i-1])
             
            # Since this weight is included
            # its value is deducted
            res = res - val[i - 1]
            w = w - wt[i - 1]
 

  
# Driver Code
total = 0
total1 = 0
for i in range(0,len(prioritize)):
  total += prioritize2[i]
  total1 += prioritize1[i]

W = int(input("How many Carbs (in grams) do you plan to consume? ")) - total
n = len(carbs)
printknapSack(W,food, carbs, protein, n,prioritize,prioritize1,prioritize2,total1,target)
# Out:
# How many Carbs (in grams) do you plan to consume? 200
# Optimum Protein(g) obtained by Knapsack 0-1 algorithm: 187
#
# The distribution of Carbohydrate and Protein as well as suggested food are displayed as below:
#
# Carbohydrate(g)	Protein	Quantity	Food
# 32		2	2		Banana
# 57		57	3		Almonds
# 29		18	1		Cashews
# 10		15	1		Brazil nuts
# 19		19	1		roasted and salted
# 3		1	1		Cantaloupe
# 2		2	1		Watercress stems, raw
# 10		5	1		Brussels sprouts
# 6		4	1		Broccoli
# 1		8	1		Beetroots
# 10		18	1		Scallops
# 3		15	1		Clams
# 1		11	1		Eggs Scrambled or fried
# 6		4	1		Buttermilk
# 6		4	1		Milk skim
# 5		4	1		Cows' milk

# %%
def fractional_knapsack(value, weight, capacity,prioritize,prioritize1,prioritize2,food,total,target):
    """Return maximum value of items and their fractional amounts.
 
    (max_value, fractions) is returned where max_value is the maximum value of
    items with total weight not more than capacity.
    fractions is a list where fractions[i] is the fraction that should be taken
    of item i, where 0 <= i < total number of items.
 
    value[i] is the value of item i and weight[i] is the weight of item i
    for 0 <= i < n where n is the number of items.
 
    capacity is the maximum weight.
    """
    # index = [0, 1, 2, ..., n - 1] for n items
    index = list(range(len(value)))
    # contains ratios of values to weight
    ratio = [v/w for v, w in zip(value, weight)]
    # index is sorted according to value-to-weight ratio in decreasing order
    index.sort(key=lambda i: ratio[i], reverse=True)

    max_value = 0
    fractions = [0]*len(value)
    print("\nThe distribution of Carbohydrate and", target ,"as well as suggested food are displayed as below: \n")
    print("Carbs\t"+target+"\tFraction\tItem")
    count = 0
    prioritize_item = prioritize[0]
    for i in range(0,len(prioritize)):
      if (prioritize_item == prioritize[i]):
        count+=1
        if(count == prioritize.count(prioritize[i])):
          print(str(prioritize2[i])+"\t"+str(prioritize1[i])+"\t"+str(count)+"\t\t"+prioritize[i])
          count = 0
      else:
        count+=1
        if(count == prioritize.count(prioritize[i])):
          print(str(prioritize2[i])+"\t"+str(prioritize1[i])+"\t"+str(count)+"\t\t"+prioritize[i])
          count = 0  
    for i in index:
        if weight[i] <= capacity:
            fractions[i] = 1
            max_value += value[i]
            capacity -= weight[i]
            print(str(weight[i])+"\t"+ str(value[i])+"\t"+str(fractions[i])+"\t\t"+food[i])
        else:
            fractions[i] = capacity/weight[i]
            factional_value = value[i]*capacity/weight[i]
            max_value += factional_value
            print(str(weight[i])+"\t"+ str(round(factional_value,2))+"\t"+str(round(fractions[i],2))+"\t\t"+food[i])
            break
 
    print('\nOptimum '+ target + "(g) obtained by fractional knapsack algorithm: " + str(round(float(max_value+total1),2)))
 
total = 0
total1 = 0 
for i in range(0,len(prioritize)):
  total += prioritize2[i]
  total1 += prioritize1[i]

item = food
value = protein
weight = carbs
capacity = int(input('How many Carbs (in grams) do you plan to consume? ')) - total
 
fractional_knapsack(value, weight, capacity,prioritize,prioritize1,prioritize2,food,total1,target)
# Out:
# How many Carbs (in grams) do you plan to consume? 200
#
# The distribution of Carbohydrate and Protein as well as suggested food are displayed as below:
#
# Carbs	Protein	Fraction	Item
# 16	1	2		Banana
# 19	19	3		Almonds
# 1	11	1		Eggs Scrambled or fried
# 1	8	1		Beetroots
# 3	15	1		Clams
# 10	18	1		Scallops
# 10	15	1		Brazil nuts
# 2	2	1		Watercress stems, raw
# 19	19	1		roasted and salted
# 5	4	1		Cows' milk
# 6	4	1		Milk skim
# 6	4	1		Buttermilk
# 6	4	1		Broccoli
# 29	18	1		Cashews
# 56	7.2	0.23		Wheat-germ cereal toasted
#
# Optimum Protein(g) obtained by fractional knapsack algorithm: 188.2

# %%
print(len(protein))
# Out:
# 39

# %%
print(len(carbs))
# Out:
# 39

# %%
print(food)
# Out:
# ["Cows' milk", 'Milk skim', 'Buttermilk', 'Eggs Scrambled or fried', 'Clams', 'Scallops', 'Asparagus', 'Beans', 'Lima', 'Lima, dry, cooked', 'Navy, baked with pork', 'Red kidney', 'Bean sprouts', 'Beet greens', 'Beetroots', 'Broccoli', 'Brussels sprouts', 'Sauerkraut', 'Steamed cabbage', 'Carrots', 'Watercress stems, raw', 'Blackberries', 'Blueberries', 'Cantaloupe', 'Cherries', 'Fresh, raw', 'Dates', 'Biscuits', 'Bran flakes', 'Bread, cracked wheat', 'Waffles', 'Wheat germ', 'Wheat-germ cereal toasted', 'Wheat meal cereal unrefined', 'Wheat, cooked', 'Bean soups', 'roasted and salted', 'Brazil nuts', 'Cashews']

# %%
print(carbs)
# Out:
# [5, 6, 6, 1, 3, 10, 4, 5, 15, 25, 19, 17, 6, 6, 1, 6, 10, 5, 6, 7, 2, 14, 26, 3, 11, 14, 76, 48, 128, 53, 40, 50, 56, 84, 18, 12, 19, 10, 29]

# %%
carbs = carbs[0:10]
protein = protein[0:10]
food = food[0:10]

# A naive recursive implementation
# of 0-1 Knapsack Problem
 
# Returns the maximum value that
# can be put in a knapsack of
# capacity W
 

# Python3 code for Dynamic Programming
# based solution for 0-1 Knapsack problem
 
# Prints the items which are put in a
# knapsack of capacity W
def printknapSack(W, name, wt, val, n,target):
    K = [[0 for w in range(W + 1)]
            for i in range(n + 1)]
             
    # Build table K[][] in bottom
    # up manner
    for i in range(n + 1):
        for w in range(W + 1):
            if i == 0 or w == 0:
                K[i][w] = 0
            elif wt[i - 1] <= w:
                K[i][w] = max(val[i - 1]
                  + K[i - 1][w - wt[i - 1]],
                               K[i - 1][w])
            else:
                K[i][w] = K[i - 1][w]
 
    # stores the result of Knapsack
    res = K[n][W]
    print("Optimum " + target +"(g) obtained by Knapsack 0-1 algorithm: " + str(res) + "\n")
    print("The distribution of Carbohydrate and Protein as well as suggested food are displayed as below: \n")
    print("Carbohydrate(g) "+ target + "(g) " +"Food")
     
    w = W
    for i in range(n, 0, -1):
        if res <= 0:
            break
        # either the result comes from the
        # top (K[i-1][w]) or from (val[i-1]
        # + K[i-1] [w-wt[i-1]]) as in Knapsack
        # table. If it comes from the latter
        # one/ it means the item is included.
        if res == K[i - 1][w]:
            continue
        else:
 
            # This item is included.
            print(wt[i - 1],val[i-1],name[i-1])
             
            # Since this weight is included
            # its value is deducted
            res = res - val[i - 1]
            w = w - wt[i - 1]
 

  
# Driver Code
print("Test correctness of knapsack 0-1 algorithm using 10 food items \n")
W = int(input("How many Carbs (in grams) do you plan to consume? "))
n = len(carbs)
printknapSack(W,food, carbs, protein, n,target)
# Out:
# Test correctness of knapsack 0-1 algorithm using 10 food items
#
# How many Carbs (in grams) do you plan to consume? 200
# Optimum Protein(g) obtained by Knapsack 0-1 algorithm: 73
#
# The distribution of Carbohydrate and Protein as well as suggested food are displayed as below:
#
# Carbohydrate(g) Protein(g) Food
# 25 9 Lima, dry, cooked
# 15 5 Lima
# 5 1 Beans
# 4 2 Asparagus
# 10 18 Scallops
# 3 15 Clams
# 1 11 Eggs Scrambled or fried
# 6 4 Buttermilk
# 6 4 Milk skim
# 5 4 Cows' milk

# %%
def fractional_knapsack(value, weight, capacity,food,target):
    """Return maximum value of items and their fractional amounts.
 
    (max_value, fractions) is returned where max_value is the maximum value of
    items with total weight not more than capacity.
    fractions is a list where fractions[i] is the fraction that should be taken
    of item i, where 0 <= i < total number of items.
 
    value[i] is the value of item i and weight[i] is the weight of item i
    for 0 <= i < n where n is the number of items.
 
    capacity is the maximum weight.
    """
    # index = [0, 1, 2, ..., n - 1] for n items
    index = list(range(len(value)))
    # contains ratios of values to weight
    ratio = [v/w for v, w in zip(value, weight)]
    # index is sorted according to value-to-weight ratio in decreasing order
    index.sort(key=lambda i: ratio[i], reverse=True)

    max_value = 0
    fractions = [0]*len(value)
    print("\nItems in Knapsack: ")
    print("Carbs\t" + target+"\tFraction\tItem")
  
    for i in index:
        if weight[i] <= capacity:
            fractions[i] = 1
            max_value += value[i]
            capacity -= weight[i]
            print(str(weight[i])+"\t"+ str(value[i])+"\t"+str(fractions[i])+"\t\t"+food[i])
        else:
            fractions[i] = capacity/weight[i]
            factional_value = value[i]*capacity/weight[i]
            max_value += factional_value
            print(str(weight[i])+"\t"+ str(factional_value)+"\t"+str(fractions[i])+"\t\t"+food[i])
            break
 
    print('Optimum Protein:', float(max_value+total1))
 


item = food[0:10]
value = protein[0:10]
weight = carbs[0:10]
capacity = int(input('How many Carbs (in grams) do you plan to consume? '))
fractional_knapsack(value, weight, capacity,food,target)
